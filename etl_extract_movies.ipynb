# %%
import pandas as pd
from pathlib import Path

path = Path.cwd() / "movies"
df_movies_metadata = pd.read_csv(path / "movies_metadata.csv", low_memory=False)
df_movies_ratings = pd.read_csv(path / "ratings.csv", low_memory=False)

# %%
df_movies_metadata.sample(5)
# Out:
#        adult                              belongs_to_collection   budget  \
# 24388  False                                                NaN        0
# 15713  False                                                NaN        0
# 5915   False                                                NaN  3000000
# 25096  False                                                NaN        0
# 40863  False  {'id': 25542, 'name': 'An American Girl Collec...        0
#
#                                                   genres  \
# 24388  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...
# 15713  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 5915   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 25096  [{'id': 9648, 'name': 'Mystery'}, {'id': 53, '...
# 40863  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
#
#                                                 homepage      id    imdb_id  \
# 24388         http://www.theasylum.cc/product.php?id=251  275318  tt3343136
# ...

# %%
df_movies_ratings.sample(5)
# Out:
#           userId  movieId  rating   timestamp
# 9325369    96310     4553     4.0  1356780513
# 22930088  238141      350     3.0   956598135
# 24863166  258506   162598     4.0  1501788880
# 18488565  191860    55290     3.5  1460235125
# 25046840  260551    95875     2.5  1493847191
